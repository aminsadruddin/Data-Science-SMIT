# %% [markdown]
# <a href="https://colab.research.google.com/github/aminsadruddin/Data-Science-SMIT/blob/main/Assignment_02_Python_Variables_and_Mathmetical_Operators_dt_30_mar_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📘 Assignment: Python – Variables, Print Statements & Mathematical Operators
# Instructions
#
# ● Use meaningful variable names.
#
# ● Apply appropriate mathematical operators.
#
# ● Use print() statements to display results clearly.
#
# ● Ensure proper formatting of output.
#
# ● Write clean and readable code.
#
#
# 🔹 Scenario-Based Questions

# %% [markdown]
# Q1: Student Result System
#
# A student has obtained the following marks:
#
# ● Subject 1: 85
#
# ● Subject 2: 78
#
# ● Subject 3: 92
#
# Tasks:
#
# ● Store the marks in variables.
#
# ● Calculate total marks.
#
# ● Calculate average marks.
#
# ● Display the results in a well-formatted sentence using print().

# %%
subject1 = 85
subject2 = 78
subject3 = 92
total_marks = subject1 + subject2 + subject3
average_marks = total_marks / 3

print("Student Results:")
print("Total Marks:", total_marks)
print("Average Marks:", average_marks)
# Out:
# Student Results:
# Total Marks: 255
# Average Marks: 85.0

# %% [markdown]
# Q2: Online Shopping Cart
# A customer purchases the following items:
#
# ● Shirt = 1200 PKR
#
# ● Shoes = 3500 PKR
#
# ● Discount = 500 PKR
#
# Tasks:
#
# ● Store all values in variables.
#
# ● Calculate the final bill after applying the discount.
#
# ● Display a detailed bill using print().

# %%
shirt = 1200
shoes = 3500
discount = 500
final_bill = shirt + shoes - discount

print("Customer's Bill:")
print(f"""
S.no      Item      Qty     Price
01        Shirt     1       {shirt}
02        Shoes     1       {shoes}
03        Discount  -       {discount}

                            ____
Total                       {final_bill}
                            ____

""")
# Out:
# Customer's Bill:
#
# S.no      Item      Qty     Price
# 01        Shirt     1       1200
# 02        Shoes     1       3500
# 03        Discount  -       500
#
#                             ____
# Total                       4200
#                             ____

# %% [markdown]
# Q3: Salary Calculation
#
# An employee has the following salary details:
#
# ● Basic Salary = 50,000 PKR
#
# ● Bonus = 20% of basic salary
#
# ● Tax = 10% of basic salary
#
# Tasks:
#
# ● Store the values in variables.
#
# ● Calculate bonus amount and tax amount.
#
# ● Calculate the final salary.
#
# ● Display a complete salary breakdown.

# %%
basic_salary = 50000
bonus = 0.2 * basic_salary
tax = 0.1 * basic_salary
final_salary = basic_salary + bonus - tax
print("Employee's Salary:")
print(f"""
Employee's Salary Breakdown:

Basic Salary       =  {basic_salary}
      Bonus        =  {bonus}
      Tax          =  {tax}


      Final Salary =  {final_salary}
      """)
# Out:
# Employee's Salary:
#
# Employee's Salary Breakdown:
#
# Basic Salary       =  50000
#       Bonus        =  10000.0
#       Tax          =  5000.0
#
#
#       Final Salary =  55000.0

# %% [markdown]
# Q4: Temperature Conversion
#
# A temperature value is given in Celsius:
#
# ● Celsius = 35
#
# Tasks:
#
# ● Convert the temperature into Fahrenheit using the appropriate formula.
#
# ● Display both Celsius and Fahrenheit values.

# %%
celsius = 35
fahrenheit = (celsius * 9/5) + 32
print(f"{celsius}°C is equal to {fahrenheit}°F")
# Out:
# 35°C is equal to 95.0°F

# %% [markdown]
# Q5: Cricket Score Analysis
#
# A player scores the following runs:
#
# ● Match 1: 45
#
# ● Match 2: 78
#
# ● Match 3: 66
#
# Tasks:
#
# ● Store the scores in variables.
#
# ● Calculate total runs.
#
# ● Calculate average runs.
#
# ● Display the performance summary.

# %%
match1 = 45
match2 = 78
match3 = 66
total_runs = match1 + match2 + match3
average_runs = total_runs / 3

print("Cricket Score Analysis:")
print(f"total runs: {total_runs}")
print(f"average runs: {average_runs}")
# Out:
# Cricket Score Analysis:
# total runs: 189
# average runs: 63.0

# %% [markdown]
# Q6: Age Calculator
#
# Given:
#
# ● Current Year = 2026
#
# ● Birth Year = 2002
#
# Tasks:
#
# ● Store the values in variables.
#
# ● Calculate the age of the person.
#
# ● Display the result in a meaningful sentence.

# %%
current_year = 2026
birth_year = 2002
age = current_year - birth_year
print(f"The age of the person is {age}")
# Out:
# The age of the person is 24

# %% [markdown]
# Q7: Rectangle Area and Perimeter
#
# A rectangle has:
#
# ● Length = 12
#
# ● Width = 8
#
# Tasks:
#
# ● Calculate the area of the rectangle.
# ● Calculate the perimeter of the rectangle.
#
# ● Display both results clearly.

# %%
length = 12
width = 8
area = length * width
perimeter = 2 * (length + width)
print(f"The area of the rectangle is {area}")
print(f"The perimeter of the rectangle is {perimeter}")
# Out:
# The area of the rectangle is 96
# The perimeter of the rectangle is 40

# %% [markdown]
# Q8: Mobile Balance System
# A user has:
#
# ● Initial Balance = 1000 PKR
#
# ● Call Charges = 150 PKR
#
# ● Internet Charges = 300 PKR
#
# Tasks:
#
# ● Store all values in variables.
#
# ● Calculate the remaining balance after deductions.
#
# ● Display the final balance along with a summary.

# %%
initial_balance = 1000
call_charges = 150
internet_charges = 300
remaining_balance = initial_balance - call_charges - internet_charges
print(f"initial balance {initial_balance}")
print(f"call charges {call_charges}")
print(f"internet charges {internet_charges}")
print(f"The remaining balance after deductions is {remaining_balance}")
# Out:
# initial balance 1000
# call charges 150
# internet charges 300
# The remaining balance after deductions is 550

# %% [markdown]
# Q9: Fuel Consumption Tracker
#
# A vehicle has:
#
# ● Total Fuel = 50 liters
#
# ● Fuel Used = 18 liters
#
# Tasks:
#
# ● Calculate the remaining fuel.
#
# ● Display the result in a clear statement.

# %%
total_fuel = 50
fuel_used = 18
remaining_fuel = total_fuel - fuel_used
print(f"The total fuel is {total_fuel}")
print(f"The fuel used is {fuel_used}")
print(f"The remaining fuel is {remaining_fuel}")
# Out:
# The total fuel is 50
# The fuel used is 18
# The remaining fuel is 32

# %% [markdown]
# Q10: Exam Percentage Calculator
#
# A student has scored:
#
# ● Math = 88
#
# ● English = 76
#
# ● Science = 91
#
# ● Total Marks = 300
#
# Tasks:
#
# ● Calculate total obtained marks.
#
# ● Calculate the percentage.
#
# ● Display the percentage with an appropriate message.

# %%
math = 88
english = 76
science = 91
total_marks = 300
total_obtained_marks = math + english + science
percentage = (total_obtained_marks / total_marks) * 100
print("maths marks are ", math)
print("english marks are ", english)
print("science marks are ", science )
print(f"The total obtained marks is {total_obtained_marks} and the percentage is {percentage}%")
# Out:
# maths marks are  88
# english marks are  76
# science marks are  91
# The total obtained marks is 255 and the percentage is 85.0%

# %% [markdown]
# Q11: Restaurant Bill Split
#
# A restaurant bill is:
#
# ● Total Bill = 4800 PKR
#
# ● Number of People = 6
#
# Tasks:
#
# ● Calculate the amount each person has to pay.
#
# ● Display the split amount clearly.

# %%
t_bill = 4800
no_of_people = 6
split_amount = t_bill / no_of_people
print(f"The amount each person has to pay is {split_amount}")
# Out:
# The amount each person has to pay is 800.0

# %% [markdown]
# Q12: Electricity Bill Calculator
# Given:
# ● Units Consumed = 250
#
# ● Cost per Unit = 18 PKR
#
# ● Fixed Charges = 500 PKR
#
# Tasks:
# ● Calculate the total electricity bill.
#
# ● Display the final bill with a breakdown

# %%
u_consumed = 250
cost_per_unit = 18
fixed_charges = 500
total_bill = (u_consumed * cost_per_unit + fixed_charges)
print(f"""Unit Consumed = {u_consumed})
Cost per Unit = {cost_per_unit}
Fixed Charges = {fixed_charges}""")
print(f"The total electricity bill is {total_bill}")
# Out:
# Unit Consumed = 250)
# Cost per Unit = 18
# Fixed Charges = 500
# The total electricity bill is 5000

# %% [markdown]
# Q13: Bank Transaction System
#
# A bank account has:
#
# ● Initial Balance = 10,000 PKR
#
# ● Deposit = 5,000 PKR
#
# ● Withdrawal = 3,000 PKR
#
# Tasks:
#
# ● Calculate the updated balance after transactions.
#
# ● Display the transaction summary and final balance.

# %%
op_balance = 10000
deposit = 5000
withdrawal = 3000
updated_balance = op_balance + deposit - withdrawal

print(f"The initial balance is {op_balance}")
print(f"The deposit is {deposit}")
print(f"The withdrawal is {withdrawal}")
print(f"The updated balance after transactions is {updated_balance}")
# Out:
# The initial balance is 10000
# The deposit is 5000
# The withdrawal is 3000
# The updated balance after transactions is 12000

# %% [markdown]
# Q14: Distance and Speed Calculation.
# A vehicle travels:
#
# ● Distance = 150 km
#
# ● Time = 3 hours
#
# Tasks:
#
# ● Calculate the speed of the vehicle.
#
# ● Display the result in km/h.

# %%
distance = 150
time = 3
speed = distance / time
print(f"The speed of the vehicle is {speed} km/h")
# Out:
# The speed of the vehicle is 50.0 km/h

# %% [markdown]
# Q15: Simple Interest Calculator.
# Given:
#
# ● Principal = 10,000 PKR
#
# ● Rate = 5%
#
# ● Time = 2 years
#
# Tasks:
#
# ● Calculate simple interest.
#
# ● Calculate total amount.
#
# ● Display both results clearly.

# %%
p_amount = 10000
rate = 0.05
time = 2
simple_interest = p_amount * rate * time
total_amount = p_amount + simple_interest

print(f"The simple interest is {simple_interest}")
print(f"The total amount is {total_amount}")
# Out:
# The simple interest is 1000.0
# The total amount is 11000.0

# %% [markdown]
# ✅ Submission Guidelines
# ● Write Python code for each question.
# ● Use comments to explain your logic.
# ● Ensure proper indentation and formatting.
# ● Submit your assignment before the deadline.
