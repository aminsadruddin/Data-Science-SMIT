# %% [markdown]
# <a href="https://colab.research.google.com/github/aminsadruddin/Data-Science-SMIT/blob/main/DS_(dt_08_mar_26)Python_Assignment_print()%2C_sep%2C_and_end.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Assignment: print(), sep, and end
#
# Institute Name: Saylani Mass IT Training
# Course Name: AI and Data Science (AI & DS)
# Instructor Name: Faisal Amin
#
# Instructions
# • Solve all questions using Python.
# • Follow the expected output format where provided.
# • Write clean and readable code.
# • Submit your solutions in a single Python file (.py) or a Jupyter Notebook.
#
# Part 1: Basic Practice

# %% [markdown]
# Part 1: Basic Practice
#
# Q1. Basic Printing Write a Python program that prints your Name, City, and Favorite Programming Language on
# separate lines using print().

# %%
print("Amin Sadruddin")
print("Karachi")
print("Python")

print("----------------")
print(" My name is Amin Sadrudin , i live in Karachi , my favorite programing language is python ")
# Out:
# Amin Sadruddin
# Karachi
# Python
# ----------------
#  My name is Amin Sadrudin , i live in Karachi , my favorite programing language is python

# %% [markdown]
# Q2. Using sep Print numbers 1, 2, 3, 4, 5 in one line separated by commas using the sep parameter.
# Expected Output:
# 1,2,3,4,5

# %%
print(1,2,3,4,5,sep=",")
# Out:
# 1,2,3,4,5

# %% [markdown]
# Q3. Custom Separator Print the words Python, Data, AI, Machine Learning separated by ' | ' using sep.

# %%
print("Python", "Data", "AI", "Machine Learning",sep="|")
# Out:
# Python|Data|AI|Machine Learning

# %% [markdown]
# Q4. Printing Numbers Print 10, 20, 30, 40 in one line separated by spaces using sep.
# Expected Output:
# 10 20 30 40

# %%
print(10,20,30,40,sep=" ")
# Out:
# 10 20 30 40

# %% [markdown]
# Q5. Using end Print 'Welcome to Python Programming' using multiple print() statements but show output in one
# line using end.
# Expected Output:
# Welcome to Python Programming

# %%
print("Welcome to Python Programming",end = " ")
# Out:
# Welcome to Python Programming

# %% [markdown]
# Part 2: Scenario-Based Questions
#
# Q6. Student Profile Program Print Name: Ahmed, Age: 21, Course: Data Science in one line separated by ' | '.
# Expected Output:
# Name: Ahmed | Age: 21 | Course: Data Science

# %%
print("Name: Ahmed | Age: 21 | Course: Data Science")
#or
print("Name: Ahmed", "Age: 21", "Course: Data Science",sep=" | ")
# Out:
# Name: Ahmed | Age: 21 | Course: Data Science
# Name: Ahmed | Age: 21 | Course: Data Science

# %% [markdown]
# Q7. Date Formatter Print 25, 12, 2026 in the format 25/12/2026 using sep.
# Expected Output:
# 25/12/2026

# %%
day = 25
month = 12
year = 2026
print(day,month,year,sep="/")
print(25,12,2026,sep="/")
print("25/12/2026")
print("25","12","2026",sep="/")
# Out:
# 25/12/2026
# 25/12/2026
# 25/12/2026
# 25/12/2026

# %% [markdown]
# Q8. Shop Receipt Program Print Item: Laptop, Price: 120000, Quantity: 1 in one line separated by ' - '.

# %%
print("Item: Laptop - Price: 120000 - Quantity: 1")
print("Item: Laptop", "Price: 120000", "Quantity: 1",sep=" - ")
# Out:
# Item: Laptop - Price: 120000 - Quantity: 1
# Item: Laptop - Price: 120000 - Quantity: 1

# %% [markdown]
# Q9. Countdown Program Print a countdown from 5 to 1 in the same line using end.
# Expected Output:
# 5 4 3 2 1

# %%
print(5,4,3,2,1,sep=" ",end=" ")
# Out:
# 5 4 3 2 1

# %% [markdown]
# Q10. Website URL Generator Print www, openai, com using sep='.'
# Expected Output:
# www.openai.com

# %%
print("www","openai","com",sep=".")
# Out:
# www.openai.com

# %% [markdown]
# Part 3: Predict the Output
#
# Q11. What will be the output of the following code?
# print("Python", "AI", "Data", sep="-")

# %%
#Python-AI-Data

# %% [markdown]
# Q12. What will be the output?
# print("Hello", end=" ")
# print("World")

# %%
#Hello World

# %% [markdown]
# Q13. What will be the output?
# print(1, 2, 3, sep="*", end=" ")
# print(4, 5)

# %%
1*2*3 4 5

# %% [markdown]
# Part 4: Debugging Questions
#
# Q14. Find and Fix the Error
# print("Python" "AI" sep="-")

# %%
print("Python","AI", sep="-")
# Out:
# Python-AI

# %% [markdown]
# Q15. Correct the Code to produce 10-20-30
# print(10 20 30 sep="-")

# %%
print(10, 20, 30 ,sep="-")
# Out:
# 10-20-30
